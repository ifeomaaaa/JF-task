# %%
from google.colab import files
from PIL import Image

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c93e1c06-02c7-40cb-acdf-3fa05f67a928" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c93e1c06-02c7-40cb-acdf-3fa05f67a928">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving imdb_top_1000.csv to imdb_top_1000.csv

# %%
import pandas as pd 
df=pd.read_csv('imdb_top_1000.csv', encoding='utf8')
df['Gross']=df['Gross'].str.replace(',','') #remove column
df = df.dropna(subset=["Gross"]) #dropnNaN because was affecting conversion to int
df = df.dropna(subset=["Certificate"]) #dropnNaN because was affecting conversion to int
df['Gross'] = df['Gross'].astype(int) #convert to int
df.sort_values(["Released_Year"], 
                    axis=0,
                    ascending=[True], 
                    inplace=True)
df.head()
# Out:
#                                            Poster_Link  \
# 127  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 194  https://m.media-amazon.com/images/M/MV5BZWFhOG...
# 193  https://m.media-amazon.com/images/M/MV5BZjEyOT...
# 320  https://m.media-amazon.com/images/M/MV5BYmRiMD...
# 319  https://m.media-amazon.com/images/M/MV5BNDVkYm...
#
#                       Series_Title Released_Year Certificate Runtime  \
# 127                        The Kid          1921      Passed  68 min
# 194                   Sherlock Jr.          1924      Passed  45 min
# 193                  The Gold Rush          1925      Passed  95 min
# 320                    The General          1926      Passed  67 min
# 319  Sunrise: A Song of Two Humans          1927      Passed  94 min
#
#                          Genre  IMDB_Rating  \
# 127      Comedy, Drama, Family          8.3
# 194    Action, Comedy, Romance          8.2
# 193   Adventure, Comedy, Drama          8.2
# 320  Action, Adventure, Comedy          8.1
# 319             Drama, Romance          8.1
#
#                                               Overview  Meta_score  \
# 127  The Tramp cares for an abandoned child, but ev...         NaN
# 194  A film projectionist longs to be a detective, ...         NaN
# 193  A prospector goes to the Klondike in search of...         NaN
# 320  When Union spies steal an engineer's beloved l...         NaN
# 319  An allegorical tale about a man fighting the g...         NaN
#
#             Director            Star1            Star2                Star3  \
# 127  Charles Chaplin  Charles Chaplin   Edna Purviance        Jackie Coogan
# 194    Buster Keaton    Buster Keaton  Kathryn McGuire           Joe Keaton
# 193  Charles Chaplin  Charles Chaplin       Mack Swain           Tom Murray
# 320   Clyde Bruckman    Buster Keaton    Buster Keaton          Marion Mack
# 319      F.W. Murnau   George O'Brien     Janet Gaynor  Margaret Livingston
#
#               Star4  No_of_Votes    Gross
# 127     Carl Miller       113314  5450000
# 194  Erwin Connelly        41985   977375
# 193   Henry Bergman       101053  5450000
# 320   Glen Cavender        81156  1033895
# 319    Bodil Rosing        46865   539540

# %%
#attempting to group dataset by year and calculate average gross per genre

df['AVG_IMDB_Rating'] = df.groupby('Genre').IMDB_Rating.transform('mean')
df.head(8)
# Out:
#                                            Poster_Link  \
# 127  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 194  https://m.media-amazon.com/images/M/MV5BZWFhOG...
# 193  https://m.media-amazon.com/images/M/MV5BZjEyOT...
# 320  https://m.media-amazon.com/images/M/MV5BYmRiMD...
# 319  https://m.media-amazon.com/images/M/MV5BNDVkYm...
# 317  https://m.media-amazon.com/images/M/MV5BNjBjND...
# 461  https://m.media-amazon.com/images/M/MV5BMzg2MW...
# 52   https://m.media-amazon.com/images/M/MV5BY2I4Mm...
#
#                        Series_Title Released_Year Certificate  Runtime  \
# 127                         The Kid          1921      Passed   68 min
# 194                    Sherlock Jr.          1924      Passed   45 min
# 193                   The Gold Rush          1925      Passed   95 min
# 320                     The General          1926      Passed   67 min
# 319   Sunrise: A Song of Two Humans          1927      Passed   94 min
# 317      La passion de Jeanne d'Arc          1928      Passed  110 min
# 461  All Quiet on the Western Front          1930           U  152 min
# 52                      City Lights          1931           G   87 min
#
#                          Genre  IMDB_Rating  \
# 127      Comedy, Drama, Family          8.3
# 194    Action, Comedy, Romance          8.2
# 193   Adventure, Comedy, Drama          8.2
# 320  Action, Adventure, Comedy          8.1
# 319             Drama, Romance          8.1
# 317  Biography, Drama, History          8.1
# 461                 Drama, War          8.0
# 52      Comedy, Drama, Romance          8.5
#
#                                               Overview  Meta_score  \
# 127  The Tramp cares for an abandoned child, but ev...         NaN
# 194  A film projectionist longs to be a detective, ...         NaN
# 193  A prospector goes to the Klondike in search of...         NaN
# 320  When Union spies steal an engineer's beloved l...         NaN
# 319  An allegorical tale about a man fighting the g...         NaN
# 317  In 1431, Jeanne d'Arc is placed on trial on ch...         NaN
# 461  A German youth eagerly enters World War I, but...        91.0
# 52   With the aid of a wealthy erratic tippler, a d...        99.0
#
#                 Director             Star1              Star2  \
# 127      Charles Chaplin   Charles Chaplin     Edna Purviance
# 194        Buster Keaton     Buster Keaton    Kathryn McGuire
# 193      Charles Chaplin   Charles Chaplin         Mack Swain
# 320       Clyde Bruckman     Buster Keaton      Buster Keaton
# 319          F.W. Murnau    George O'Brien       Janet Gaynor
# 317  Carl Theodor Dreyer  Maria Falconetti     Eugene Silvain
# 461      Lewis Milestone         Lew Ayres      Louis Wolheim
# 52       Charles Chaplin   Charles Chaplin  Virginia Cherrill
#
#                    Star3           Star4  No_of_Votes    Gross  \
# 127        Jackie Coogan     Carl Miller       113314  5450000
# 194           Joe Keaton  Erwin Connelly        41985   977375
# 193           Tom Murray   Henry Bergman       101053  5450000
# 320          Marion Mack   Glen Cavender        81156  1033895
# 319  Margaret Livingston    Bodil Rosing        46865   539540
# 317         André Berley  Maurice Schutz        47676    21877
# 461            John Wray     Arnold Lucy        57318  3270000
# 52          Florence Lee     Harry Myers       167839    19181
#
#      AVG_IMDB_Rating
# 127         8.020000
# 194         8.200000
# 193         7.871429
# 320         7.877778
# 319         7.937931
# 317         7.986957
# 461         8.100000
# 52          7.880000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(99,75))
ax.bar(df["Genre"], df["AVG_IMDB_Rating"], color="black")
plt.title("Average IMDB Rating per Genre") 
plt.xlabel("Genre")
plt.ylabel("Average IMDB Rating")
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
plt.show()
