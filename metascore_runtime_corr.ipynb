# %%
from google.colab import files
from PIL import Image

uploaded = files.upload()
# Out:
#      <input type="file" id="files-d6197bf7-bf54-4eb4-94b9-8f333c2c47bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6197bf7-bf54-4eb4-94b9-8f333c2c47bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving imdb_top_1000.csv to imdb_top_1000.csv

# %%
import pandas as pd 
df=pd.read_csv('imdb_top_1000.csv', encoding='utf8')
df['Runtime']=df['Runtime'].str.replace('min','') #remove column
df = df.dropna(subset=["Runtime"]) #dropnNaN because was affecting conversion to int
df['Runtime'] = df['Runtime'].astype(int) #convert to int
df.sort_values(["Runtime"], 
                    axis=0,
                    ascending=[True], 
                    inplace=True)
df.head()
# Out:
#                                            Poster_Link  Series_Title  \
# 194  https://m.media-amazon.com/images/M/MV5BZWFhOG...  Sherlock Jr.
# 567  https://m.media-amazon.com/images/M/MV5BMjMyYj...        Freaks
# 320  https://m.media-amazon.com/images/M/MV5BYmRiMD...   The General
# 127  https://m.media-amazon.com/images/M/MV5BZjhhMT...       The Kid
# 717  https://m.media-amazon.com/images/M/MV5BYmYxZG...     Duck Soup
#
#     Released_Year Certificate  Runtime                      Genre  \
# 194          1924      Passed       45    Action, Comedy, Romance
# 567          1932         NaN       64              Drama, Horror
# 320          1926      Passed       67  Action, Adventure, Comedy
# 127          1921      Passed       68      Comedy, Drama, Family
# 717          1933         NaN       69       Comedy, Musical, War
#
#      IMDB_Rating                                           Overview  \
# 194          8.2  A film projectionist longs to be a detective, ...
# 567          7.9  A circus' beautiful trapeze artist agrees to m...
# 320          8.1  When Union spies steal an engineer's beloved l...
# 127          8.3  The Tramp cares for an abandoned child, but ev...
# 717          7.8  Rufus T. Firefly is named president/dictator o...
#
#      Meta_score         Director            Star1            Star2  \
# 194         NaN    Buster Keaton    Buster Keaton  Kathryn McGuire
# 567        80.0     Tod Browning     Wallace Ford      Leila Hyams
# 320         NaN   Clyde Bruckman    Buster Keaton    Buster Keaton
# 127         NaN  Charles Chaplin  Charles Chaplin   Edna Purviance
# 717        93.0      Leo McCarey     Groucho Marx       Harpo Marx
#
#               Star3           Star4  No_of_Votes      Gross
# 194      Joe Keaton  Erwin Connelly        41985    977,375
# 567  Olga Baclanova     Roscoe Ates        42117        NaN
# 320     Marion Mack   Glen Cavender        81156  1,033,895
# 127   Jackie Coogan     Carl Miller       113314  5,450,000
# 717      Chico Marx      Zeppo Marx        55581        NaN

# %%
df['AVG_Meta_score'] = df.groupby('Runtime').Meta_score.transform('mean')
df = df.dropna(subset=["AVG_Meta_score"]) #dropnNaN because was affecting conversion to int
df.head(8)
# Out:
#                                            Poster_Link          Series_Title  \
# 567  https://m.media-amazon.com/images/M/MV5BMjMyYj...                Freaks
# 717  https://m.media-amazon.com/images/M/MV5BYmYxZG...             Duck Soup
# 719  https://m.media-amazon.com/images/M/MV5BMTQ0Nj...          Frankenstein
# 920  https://m.media-amazon.com/images/M/MV5BMjEzMj...   The Secret of Kells
# 876  https://m.media-amazon.com/images/M/MV5BYjllMm...     The Invisible Man
# 694  https://m.media-amazon.com/images/M/MV5BYjhhMD...    La planète sauvage
# 318  https://m.media-amazon.com/images/M/MV5BM2QwYW...            The Circus
# 462  https://m.media-amazon.com/images/M/MV5BMTEyMT...  Bronenosets Potemkin
#
#     Released_Year Certificate  Runtime                         Genre  \
# 567          1932         NaN       64                 Drama, Horror
# 717          1933         NaN       69          Comedy, Musical, War
# 719          1931      Passed       70         Drama, Horror, Sci-Fi
# 920          2009         NaN       71  Animation, Adventure, Family
# 876          1933       TV-PG       71                Horror, Sci-Fi
# 694          1973           U       72             Animation, Sci-Fi
# 318          1928      Passed       72               Comedy, Romance
# 462          1925         NaN       75      Drama, History, Thriller
#
#      IMDB_Rating                                           Overview  \
# 567          7.9  A circus' beautiful trapeze artist agrees to m...
# 717          7.8  Rufus T. Firefly is named president/dictator o...
# 719          7.8  Dr. Frankenstein dares to tamper with life and...
# 920          7.6  A young boy in a remote medieval outpost under...
# 876          7.7  A scientist finds a way of becoming invisible,...
# 694          7.8  On a faraway planet where blue giants rule, op...
# 318          8.1  The Tramp finds work and the girl of his dream...
# 462          8.0  In the midst of the Russian Revolution of 1905...
#
#      Meta_score              Director              Star1             Star2  \
# 567        80.0          Tod Browning       Wallace Ford       Leila Hyams
# 717        93.0           Leo McCarey       Groucho Marx        Harpo Marx
# 719        91.0           James Whale        Colin Clive        Mae Clarke
# 920        81.0            Tomm Moore        Nora Twomey      Evan McGuire
# 876        87.0           James Whale       Claude Rains     Gloria Stuart
# 694        73.0           René Laloux     Barry Bostwick    Jennifer Drake
# 318        90.0       Charles Chaplin    Charles Chaplin     Merna Kennedy
# 462        97.0  Sergei M. Eisenstein  Aleksandr Antonov  Vladimir Barskiy
#
#                     Star3          Star4  No_of_Votes    Gross  AVG_Meta_score
# 567        Olga Baclanova    Roscoe Ates        42117      NaN            80.0
# 717            Chico Marx     Zeppo Marx        55581      NaN            93.0
# 719         Boris Karloff     John Boles        65341      NaN            91.0
# 920       Brendan Gleeson     Mick Lally        31779  686,383            84.0
# 876      William Harrigan  Henry Travers        30683      NaN            84.0
# 694           Eric Baugin    Jean Topart        25229  193,817            81.5
# 318      Al Ernest Garcia  Harry Crocker        30205      NaN            81.5
# 462  Grigoriy Aleksandrov    Ivan Bobrov        53054   50,970            96.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(30,10))
ax.scatter(df["Runtime"], df["Meta_score"], color="red")
plt.title("Meta Score and Runtime Correlation") 
plt.xlabel("Runtime")
plt.ylabel("Meta Score") 
sns.lmplot(x="Runtime", y="Meta_score", data=df); #regression line
plt.show()

# %%
df['Meta_score'].corr(df['Runtime'])
# Out:
# -0.031451971885030815
